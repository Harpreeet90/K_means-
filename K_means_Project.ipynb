# %%
##Customer Segmentation Using K Means Clustering##

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
CS = pd.read_csv("Mall_Customers.csv")

# %%
CS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
CS.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
CS.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
CS.drop(["CustomerID"], axis = 1, inplace=True)

# %%
plt.figure(figsize=(10,6))
plt.title("Ages Frequency")
sns.axes_style("dark")
sns.violinplot(y=df["Age"])
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.boxplot(y=CS["Spending Score (1-100)"], color="green")
plt.subplot(1,2,2)
sns.boxplot(y=CS["Annual Income (k$)"])
plt.show()

# %%
genders = CS.Gender.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(10,4))
sns.barplot(x=genders.index, y=genders.values)
plt.show()

# %%
age18_25 = CS.Age[(df.Age <= 25) & (df.Age >= 18)]
age26_35 = CS.Age[(df.Age <= 35) & (df.Age >= 26)]
age36_45 = CS.Age[(df.Age <= 45) & (df.Age >= 36)]
age46_55 = CS.Age[(df.Age <= 55) & (df.Age >= 46)]
age55above = df.Age[df.Age >= 56]

x = ["18-25","26-35","36-45","46-55","55+"]
y = [len(age18_25.values),len(age26_35.values),len(age36_45.values),len(age46_55.values),len(age55above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=x, y=y, palette="rocket")
plt.title("Number of Customer and Ages")
plt.xlabel("Age")
plt.ylabel("Number of Customer")
plt.show()

# %%
ss1_20 = CS["Spending Score (1-100)"][(CS["Spending Score (1-100)"] >= 1) & (CS["Spending Score (1-100)"] <= 20)]
ss21_40 = CS["Spending Score (1-100)"][(CS["Spending Score (1-100)"] >= 21) & (df["Spending Score (1-100)"] <= 40)]
ss41_60 = CS["Spending Score (1-100)"][(CS["Spending Score (1-100)"] >= 41) & (CS["Spending Score (1-100)"] <= 60)]
ss61_80 = CS["Spending Score (1-100)"][(CS["Spending Score (1-100)"] >= 61) & (CS["Spending Score (1-100)"] <= 80)]
ss81_100 =CS["Spending Score (1-100)"][(CS["Spending Score (1-100)"] >= 81) & (CS["Spending Score (1-100)"] <= 100)]

ssx = ["1-20", "21-40", "41-60", "61-80", "81-100"]
ssy = [len(ss1_20.values), len(ss21_40.values), len(ss41_60.values), len(ss61_80.values), len(ss81_100.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=ssx, y=ssy, palette="nipy_spectral_r")
plt.title("Spending Scores")
plt.xlabel("Score")
plt.ylabel("Number of Customer Having the Score")
plt.show()

# %%
ai0_30 = CS["Annual Income (k$)"][(CS["Annual Income (k$)"] >= 0) & (CS["Annual Income (k$)"] <= 30)]
ai31_60 = CS["Annual Income (k$)"][(CS["Annual Income (k$)"] >= 31) & (CS["Annual Income (k$)"] <= 60)]
ai61_90 = CS["Annual Income (k$)"][(CS["Annual Income (k$)"] >= 61) & (CS["Annual Income (k$)"] <= 90)]
ai91_120 = CS["Annual Income (k$)"][(CS["Annual Income (k$)"] >= 91) & (CS["Annual Income (k$)"] <= 120)]
ai121_150 = CS["Annual Income (k$)"][(CS["Annual Income (k$)"] >= 121) & (CS["Annual Income (k$)"] <= 150)]

aix = ["$ 0 - 30,000", "$ 30,001 - 60,000", "$ 60,001 - 90,000", "$ 90,001 - 120,000", "$ 120,001 - 150,000"]
aiy = [len(ai0_30.values), len(ai31_60.values), len(ai61_90.values), len(ai91_120.values), len(ai121_150.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=aix, y=aiy, palette="Set2")
plt.title("Annual Incomes")
plt.xlabel("Income")
plt.ylabel("Number of Customer")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

sns.set_style("white")
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(CS.Age, df["Annual Income (k$)"], CS["Spending Score (1-100)"], c='red', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()

# %%
from sklearn.cluster import KMeans

wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(df.iloc[:,1:])
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,11),wcss, linewidth=2, color="blue", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()
# Out:
# C:\Users\HARPREET\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\HARPREET\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\HARPREET\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
km = KMeans(n_clusters=5)
clusters = km.fit_predict(CS.iloc[:,1:])

CS["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(CS.Age[CS.label == 0], CS["Annual Income (k$)"][CS.label == 0], CS["Spending Score (1-100)"][CS.label == 0], c='blue', s=60)
ax.scatter(CS.Age[CS.label == 1], CS["Annual Income (k$)"][CS.label == 1], CS["Spending Score (1-100)"][CS.label == 1], c='red', s=60)
ax.scatter(CS.Age[CS.label == 2], CS["Annual Income (k$)"][CS.label == 2], CS["Spending Score (1-100)"][CS.label == 2], c='green', s=60)
ax.scatter(CS.Age[CS.label == 3], CS["Annual Income (k$)"][CS.label == 3], CS["Spending Score (1-100)"][CS.label == 3], c='orange', s=60)
ax.scatter(CS.Age[CS.label == 4], CS["Annual Income (k$)"][CS.label == 4], CS["Spending Score (1-100)"][CS.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()
# Out:
# C:\Users\HARPREET\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
